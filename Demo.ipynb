# %%
# !git clone https://github.com/CUAI-CAU/2022_Summer_NLP_T12.git
# Out:
# Cloning into '2022_Summer_NLP_T12'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 104 (delta 9), reused 0 (delta 0), pack-reused 83
# Receiving objects: 100% (104/104), 2.01 MiB | 9.57 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# Change the directory to the git
# %cd ./2022_Summer_NLP_T12

# %%
# Checking
# !pwd

# %%
# !pip install -r requirements.txt

# %%
# !python script/train.py --train_gen --train_gen_file intro.txt --gen_epochs 2
# Out:
# ...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/modeling_auto.py:1002: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# ...

# %%
# !python script/train.py --gpus 1 --train_para --accelerator ddp --train_file ko-ko-pair.csv
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/modeling_auto.py:1002: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# ...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'BertTokenizer'.
# ...

# %%
# !python script/train.py --test --model_params_gen /home/cuai5th/CUAI_2022/HeejaeSuh/model/test_export_100_5.pkl --model_params_para /home/cuai5th/CUAI_2022/HeejaeSuh/model/paraKor-epoch=50-train_loss=18.75.ckpt --text_file input_example.txt
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# /home/cuai5th/anaconda3/envs/pytorch1.8_p38/lib/python3.8/site-packages/transformers/models/auto/modeling_auto.py:878: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Downloading: 100%|██████████████████████████████| 615/615 [00:00<00:00, 494kB/s]
# Downloading: 100%|███████████████████████████| 502M/502M [00:14<00:00, 36.4MB/s]
# Downloading: 100%|███████████████████████████| 82.0/82.0 [00:00<00:00, 73.4kB/s]
# ...
